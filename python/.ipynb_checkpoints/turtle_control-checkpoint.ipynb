# %%
from multiTurtleSim import *

# %%
sim  = MultiTurtleSim(
                timestep= 0.5,
                 botDiameter=0.35, 
                wheelDist=0.23,
                 neighborDist=2,
                 maxNeighbors=2,
                 timeHorizon=10,
                 timeHorizonObst=10,
                 maxSpeed=0.65,
                velocity = np.array([0,0])
)

# %%
sim.addBot(np.array([10,0]),0,np.array([-1,0]))
# Out:
#  waiting for bot 1 to initialize its pose  ....('turtle1 initialized with pose ', array([10.,  0.]), ' orientation ', 0.0)
#  waiting for bot 1 to initialize its pose  ....Add bot 1 with pos  [10.175  0.   ]

# %%
# sim.addBot(np.array([-10,0]),3.14,np.array([1,0]))

# %%
while not sim.done():
    sim.step()
# Out:
# (1, ' get command ', linear:
#   x: -0.6499999761581421
#   y: 0
#   z: 0
# angular:
#   x: 0
#   y: 0
#   z: 0.0)
